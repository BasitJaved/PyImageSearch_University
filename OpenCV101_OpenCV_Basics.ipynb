# %%
import cv2 as cv
import numpy as np
from google.colab.patches import cv2_imshow as imshow #using cv2_imshow because cv.imshow does not work in google colab

# %%
#reading the image
img = cv.imread('road2.jpg')
(h, w, c) = img.shape[:3]

#dispalying width height and number of channels
print(f'Height of image: {h} pixels')
print(f'Width of image: {w} pixels')
print(f'No of Channels: {h}')

#displaying the image
imshow(img)

#writing image
cv.imwrite('Road2.png', img)
# Out:
# Height of image: 720 pixels
# Width of image: 1280 pixels
# No of Channels: 720
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F80E99D6250>
# True
